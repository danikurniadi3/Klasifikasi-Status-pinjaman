# %%
import pandas as pd

data = pd.read_csv('dataset-bank-abc.csv')
data.head()
# Out:
#   ID_Nasabah JenisKelamin StatusPernikahan  JumTanggungan    Pendidikan  \
# 0   LP001002         Male               No              0      Graduate
# 1   LP001003         Male              Yes              1      Graduate
# 2   LP001005         Male              Yes              0      Graduate
# 3   LP001006         Male              Yes              0  Not Graduate
# 4   LP001008         Male               No              0      Graduate
#
#   Wiraswasta  IncomeNasabah  IncomePasangan  JumlahPinjaman  \
# 0         No           5849               0             128
# 1         No           4583            1508             128
# 2        Yes           3000               0              66
# 3         No           2583            2358             120
# 4         No           6000               0             141
#
#    JangkaWaktuPinjaman  Credit_History WilayahTempatTinggal StatusPinjaman
# 0                  360               1                Urban              Y
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data['JenisKelamin'] = enc.fit_transform(data['JenisKelamin'].values)
data['StatusPernikahan'] = enc.fit_transform(data['StatusPernikahan'].values)
data['Pendidikan'] = enc.fit_transform(data['Pendidikan'].values)
data['Wiraswasta'] = enc.fit_transform(data['Wiraswasta'].values)
data['WilayahTempatTinggal'] = enc.fit_transform(data['WilayahTempatTinggal'].values)
data['StatusPinjaman'] = enc.fit_transform(data['StatusPinjaman'].values)

# %%
data.head()
# Out:
#   ID_Nasabah  JenisKelamin  StatusPernikahan  JumTanggungan  Pendidikan  \
# 0   LP001002             1                 0              0           0
# 1   LP001003             1                 1              1           0
# 2   LP001005             1                 1              0           0
# 3   LP001006             1                 1              0           1
# 4   LP001008             1                 0              0           0
#
#    Wiraswasta  IncomeNasabah  IncomePasangan  JumlahPinjaman  \
# 0           0           5849               0             128
# 1           0           4583            1508             128
# 2           1           3000               0              66
# 3           0           2583            2358             120
# 4           0           6000               0             141
#
#    JangkaWaktuPinjaman  Credit_History  WilayahTempatTinggal  StatusPinjaman
# 0                  360               1                     2               1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Nasabah            614 non-null    object
#  1   JenisKelamin          614 non-null    int64
#  2   StatusPernikahan      614 non-null    int64
#  3   JumTanggungan         614 non-null    int64
#  4   Pendidikan            614 non-null    int64
#  5   Wiraswasta            614 non-null    int64
#  6   IncomeNasabah         614 non-null    int64
#  7   IncomePasangan        614 non-null    int64
#  8   JumlahPinjaman        614 non-null    int64
#  9   JangkaWaktuPinjaman   614 non-null    int64
#  10  Credit_History        614 non-null    int64
#  11  WilayahTempatTinggal  614 non-null    int64
#  12  StatusPinjaman        614 non-null    int64
# dtypes: int64(12), object(1)
# memory usage: 62.5+ KB

# %%
atr_data = data.drop(columns=['StatusPinjaman','ID_Nasabah','JenisKelamin','WilayahTempatTinggal','Wiraswasta','Pendidikan','StatusPernikahan'])

atr_data.head()
# Out:
#    JumTanggungan  IncomeNasabah  IncomePasangan  JumlahPinjaman  \
# 0              0           5849               0             128
# 1              1           4583            1508             128
# 2              0           3000               0              66
# 3              0           2583            2358             120
# 4              0           6000               0             141
#
#    JangkaWaktuPinjaman  Credit_History
# 0                  360               1
# 1                  360               1
# 2                  360               1
# 3                  360               1
# 4                  360               1

# %%
cls_data = data['StatusPinjaman']

# %%
cls_data.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: StatusPinjaman, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , confusion_matrix , classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
xtrain, xtest, ytrain, ytest = train_test_split(atr_data,cls_data ,test_size=0.2, random_state=600)
tree_data = DecisionTreeClassifier (random_state=600)
tree_data.fit (xtrain, ytrain)
# Out:
# DecisionTreeClassifier(random_state=600)

# %%
y_pred = tree_data.predict(xtest)
cm = confusion_matrix(ytest, y_pred)
print("Confusion Matrix  :")
print(cm)
akurasi = classification_report(ytest, y_pred)
print("Tingat Akurasi Algoritma")
print("Akurasi :",akurasi)
akurasi = accuracy_score(ytest, y_pred)
print("Tingkat Akurasi : %d persen"%(akurasi*100))
# Out:
# Confusion Matrix  :
# [[22 22]
#  [12 67]]
# Tingat Akurasi Algoritma
# Akurasi :               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.56        44
#            1       0.75      0.85      0.80        79
#
#     accuracy                           0.72       123
#    macro avg       0.70      0.67      0.68       123
# weighted avg       0.71      0.72      0.71       123
#
# Tingkat Akurasi : 72 persen

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree_data, out_file="tree_status_pinjaman.dot",class_names=("1","0"),
                feature_names=atr_data.columns, impurity=False , filled=True)

# %%
import graphviz

with open ("tree_status_pinjaman.dot") as fig:
  dot_graph = fig.read()
graph = graphviz.Source(dot_graph)
graph.view()
# Out:
# 'Source.gv.pdf'

# %%
from sklearn.tree import export_text

# %%
rules = export_text(tree_data,feature_names=list(xtrain.columns))
print(rules)
# Out:
# |--- Credit_History <= 0.50
# |   |--- JumlahPinjaman <= 547.50
# |   |   |--- IncomeNasabah <= 6266.50
# |   |   |   |--- IncomeNasabah <= 6176.00
# |   |   |   |   |--- IncomeNasabah <= 3594.50
# |   |   |   |   |   |--- IncomePasangan <= 6623.00
# |   |   |   |   |   |   |--- JumlahPinjaman <= 61.50
# |   |   |   |   |   |   |   |--- JangkaWaktuPinjaman <= 240.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- JangkaWaktuPinjaman >  240.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- JumlahPinjaman >  61.50
# |   |   |   |   |   |   |   |--- JangkaWaktuPinjaman <= 240.00
# |   |   |   |   |   |   |   |   |--- JumlahPinjaman <= 100.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- JumlahPinjaman >  100.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- JangkaWaktuPinjaman >  240.00
# ...
